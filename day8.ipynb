# %%
print('hello world')
# Out:
# hello world

# %%
print('welcome to you in upflairs!')
# Out:
# welcome to you in upflairs!

# %%
import os

# %%
pwd
# Out:
# 'd:\\18 june'

# %%
os.getcwd()        # current working directory
# Out:
# 'd:\\18 june'

# %%
os.listdir()           #jitni hamne file executed ki hui h un sbki  list are in there
# Out:
# ['a.py',
#  'age.py',
#  'atm.py',
#  'b.py',
#  'day2.py',
#  'day3.py',
#  'day4.py',
#  'day5.py',
#  'day6.py',
#  'day7.py',
#  'day8.ipynb',
#  'day9.ipynb',
#  'day9i.ipynb',
#  'demo',
#  'demo.txt',
#  'employ.py',
#  'first.py',
#  'hello.txt',
#  'manager.py',
#  'opp.ipynb',
#  'yash.ipynb',
#  '__pycache__']

# %%
ls                #ls means to drive data from whjich date and time identifiers
# Out:
#  Volume in drive D is DATA
#  Volume Serial Number is A616-5466
#
#  Directory of d:\18 june
#
#
#  Directory of d:\18 june
#
#
#  Directory of d:\18 june
#
#
#  Directory of d:\18 june
#
#
#  Directory of d:\18 june
#
#
#  Directory of d:\18 june
#
#
#  Directory of d:\18 june
#
#
#  Directory of d:\18 june
#
#
#  Directory of d:\18 june
#
#
#  Directory of d:\18 june
#
#
#  Directory of d:\18 june
# File Not Found

# %%
# GUI  ,  CLI  ,  PROGRAMING

# %%
mkdir demo        # here file is executed at the initial moment     (GUI)

# %%
rmdir demo     # it removes the folder at initial moment which we wnt to remove   (GUI)

# %%
os.mkdir('demo1')          #it is also the part to add the file folder(CLI)

# %%
os.rmdir('demo1')           #it is also the part of removing the file in it   (CLI)

# %%
# Exception handling
name = input("plz enter your name : ")
age = int(input("plz enter your age : "))

print("my name is :",name)
print("and my age is :",age)

print("I am very important , plz execute me !")

# error --> unwanted or unexpected error
# Out:
# my name is : vivek
# and my age is : 19
# I am very important , plz execute me !

# %%
# try  ,  except ,  else  ,  finally

try:    # yes or no
    name = input("plz enter your name : ")
    age = int(input("plz enter your age : "))

    print("my name is :",name)
    print("and my age is :",age)

except:    # yes error
    print("error is occured!")

else:  # no error
    print("congratulation you dont have any error!")
    print("error is not occured!")

finally: 
    print("i will be always!")



print("I am very important , plz execute me !")
# Out:
# error is occured!
# i will be always!
# I am very important , plz execute me !

# %%
ls = [1,2,3]
ls
# Out:
# [1, 2, 3]

# %%
rmdir (hello.text)

# %%
#   <<<<<<<< file handling   >>>>>>>>>>


# open(file_address , mode)
file = open("hello.txt",'r')   # reading  
data = file.read()
print(data)
file.close()
# Out:
# vivek, yash, rishi , ravivivek, yash, rishi , ravivivek, yash, rishi , ravivivek, yash, rishi , ravivivek, yash, rishi , ravi

# %%
file = open('hello.txt','r')   # reading  
data = file.read()
print(data)
file.close()
# Out:
# vivek, yash, rishi , ravivivek, yash, rishi , ravivivek, yash, rishi , ravivivek, yash, rishi , ravivivek, yash, rishi , ravi

# %%
file = open('hello.txt')   # by default mode = r 
file.close()

# %%
message = "hello welcome to you from upflairs"
message = "vivek, yash, rishi , ravi"
# w == writing
with open('hello.txt','w') as file:
    # data = file.read() 
    #print(data)
    file.write(message)
    

    ## NOTE w---> past  data remove
    ## w--> itwill create new file

# %%
message = "hello welcome to you from upflairs"
message = "vivek, yash, rishi , ravi"
# w == writing
with open('hello.txt','w') as file:
    # data = file.read() 
    #print(data)
    file.write(message)
   #append mode
   ## a ==>it will create new file if not available

# %%
message = "hello welcome to you from upflairs"
message = "vivek, yash, rishi , ravi"
# w == writing
with open('hello.txt','a') as file:
    # data = file.read() 
    #print(data)
    file.write(message)
    file.close()

# %%
message = "welcome to you from upflairs"
message="\n yash,vivek,rishi,kapil"
with open('demo.txt','a') as file:
    file.write(message)
    print(message)
# Out:
#  yash,vivek,rishi,kapil

# %%
message  = "welcome from upflairs"
# w == writing
with open('demo.txt','a') as file:
    # data = file.read() 
    #print(data)
    for i in range(1000):
        file.write(message)
        print(message)
# Out:
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# welcome from upflairs
# ...
